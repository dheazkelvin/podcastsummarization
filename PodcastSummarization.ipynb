# %% [markdown]
# ####Download Video form Youtube

# %%
#Library for downloading youtube vid
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from pytube import YouTube

# %%
youtube_video = "https://youtu.be/2j8CqOCmEDM"

# %%
yt = YouTube(youtube_video)

# %%
#Download audio from youtube
#filtering only mp4 (.filter)
#return objek yang memenuhi kondisi (.first)

yt.streams\
    .filter(only_audio = True, file_extension = 'mp4')\
    .first()\
    .download(filename ='audio.mp4')
# Out:
# '/content/audio.mp4'

# %%
import IPython.display as display

# %%
path = "/content/audio.mp4"

# %%
display.Audio(path, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#convert mp4 to wav
! ffmpeg -i audio.mp4 -acodec pcm_s16le -ar 16000 audio.wav
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'audio.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2023-10-18T06:59:24.000000Z
#   Duration: 00:03:54.66, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-18T06:59:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio.wav':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, stereo, s16, 512 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-18T06:59:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=   14666kB time=00:03:54.65 bitrate= 512.0kbits/s speed= 481x
# video:0kB audio:14666kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000519%

# %% [markdown]
# ####ASR

# %%
# !pip install torch --upgrade
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Collecting torch
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 44.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 52.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 57.1 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 6.0 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 82.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 torch-2.1.2

# %%
# !pip install huggingsound --upgrade
# Out:
# Collecting huggingsound
#   Downloading huggingsound-0.1.6-py3-none-any.whl (28 kB)
# Collecting datasets<3.0.0,>=2.6.1 (from huggingsound)
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 11.9 MB/s eta 0:00:00
# Collecting jiwer<3.0.0,>=2.5.1 (from huggingsound)
#   Downloading jiwer-2.6.0-py3-none-any.whl (20 kB)
# Collecting librosa<0.10.0,>=0.9.2 (from huggingsound)
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 17.5 MB/s eta 0:00:00
# Collecting torch!=1.12.0,<1.13.0,>=1.7 (from huggingsound)
#   Downloading torch-1.12.1-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.23.1 in /usr/local/lib/python3.10/dist-packages (from huggingsound) (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (10.0.1)
# Collecting pyarrow-hotfix (from datasets<3.0.0,>=2.6.1->huggingsound)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets<3.0.0,>=2.6.1->huggingsound)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (3.4.1)
# Collecting multiprocess (from datasets<3.0.0,>=2.6.1->huggingsound)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound) (6.0.1)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer<3.0.0,>=2.5.1->huggingsound) (8.1.7)
# Collecting rapidfuzz==2.13.7 (from jiwer<3.0.0,>=2.5.1->huggingsound)
#   Downloading rapidfuzz-2.13.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 67.3 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (1.3.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa<0.10.0,>=0.9.2->huggingsound)
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 54.5 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (0.58.1)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound) (1.8.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,<1.13.0,>=1.7->huggingsound) (4.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.23.1->huggingsound) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.23.1->huggingsound) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.23.1->huggingsound) (0.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound) (4.0.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa<0.10.0,>=0.9.2->huggingsound) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa<0.10.0,>=0.9.2->huggingsound) (4.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.6.1->huggingsound) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.6.1->huggingsound) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.6.1->huggingsound) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.6.1->huggingsound) (2023.11.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa<0.10.0,>=0.9.2->huggingsound) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa<0.10.0,>=0.9.2->huggingsound) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.6.1->huggingsound) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.6.1->huggingsound) (2023.3.post1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.10.0,>=0.9.2->huggingsound) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets<3.0.0,>=2.6.1->huggingsound) (1.16.0)
# Installing collected packages: torch, rapidfuzz, pyarrow-hotfix, dill, resampy, multiprocess, jiwer, librosa, datasets, huggingsound
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.1
#     Uninstalling librosa-0.10.1:
#       Successfully uninstalled librosa-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# Successfully installed datasets-2.16.1 dill-0.3.7 huggingsound-0.1.6 jiwer-2.6.0 librosa-0.9.2 multiprocess-0.70.15 pyarrow-hotfix-0.6 rapidfuzz-2.13.7 resampy-0.4.2 torch-1.12.1

# %%
from huggingsound import SpeechRecognitionModel
import torch

# %%
#Checking GPU if CUDA enabled -> output cuda, if not output will be cpu
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cuda'

# %%
# #pretrained model using wav2vec2 for
# model = SpeechRecognitionModel("cahya/whisper-medium-id", device=device)

# %% [markdown]
# ####Audio Slicing

# %%
import librosa
import soundfile as sf

# %%
input_file ='/content/audio.wav'

# %%
# to retrieve the sampling rate of an audio file
print(librosa.get_samplerate(input_file))

stream = librosa.stream(
    input_file,
    block_length=60, #Slicing duration to 60 seconds
    frame_length=8000, #length of each audio frame per block
    hop_length=8000 #overlap between gap, set to 16000 means that there is no overlap
)
# Out:
# 16000

# %%
#Save slicing result from "stream"
for i, speech in enumerate(stream):
  sf.write(f'{i}.wav', speech, 16000) #to write audio data to a file

# %%
i
# Out:
# 7

# %% [markdown]
# ####Audio Transcript (Speech to Text)

# %%
#Generate list of audio
audio_path = []
for a in range(i+1):
  audio_path.append(f'/content/{a}.wav')

# %%
audio_path
# Out:
# ['/content/0.wav',
#  '/content/1.wav',
#  '/content/2.wav',
#  '/content/3.wav',
#  '/content/4.wav',
#  '/content/5.wav',
#  '/content/6.wav',
#  '/content/7.wav']

# %%
# #transcript audio_path and stored in the transcriptions
# transcriptions = model.transcribe(audio_path)

# %%
from transformers import pipeline
transcriber = pipeline(
  "automatic-speech-recognition",
  model="cahya/whisper-medium-id"
)
transcriber.model.config.forced_decoder_ids = (
  transcriber.tokenizer.get_decoder_prompt_ids(
    language="id",
    task="transcribe"
  )
)
transcriptions = transcriber(audio_path)
# Out:
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/832 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %%
full_transcript = ""

# %%
for i in transcriptions:
    if 'text' in i:
        full_transcript += i['text'] + " "  # Add space between texts if needed

# %%
#length of characters
len(full_transcript)
# Out:
# 628

# %%
import pprint

# %%
pprint.pprint(full_transcript)
# Out:
# ('Yang Mulia, Presiden Xi Jinping. Yang mulia para leaders hadirin sekalian '
#  'yang saya hormati. Pemimpinan terbelah kerjasama TRI tidak boleh '
#  'dipolitisasi. Ini membutuhkan upaya kita bersama dalam menjaga nilai-nilai '
#  'utama agar inisiatif ini semakin kuat dan semakin berdampak. Ada tiga hal '
#  'yang ingin saya sampaikan. untuk menjalankan proyek nasionalnya secara '
#  'mandiri, karena "sense of ownership" sangat penting untuk keberangsungan '
#  'proyek. pembangunan ibu kota baru (IKN), transisi energi, dan hilirisasi '
#  'industri.  dan pemanfaatan produk dalam negeri. Pemimpinan Negara Negara '
#  'Berkembang melalui BRI Semoga berjaya untuk kami. ')

# %%
#Save full_transcript to txt file
transcript_file = "/content/transcript.txt"

#open file
with open(transcript_file, "w") as file:
  file.write(full_transcript)

print("Transcript saved to", transcript_file)
# Out:
# Transcript saved to /content/transcript.txt

# %%
with open("transcript.txt", "r") as file:
  trans = file.read().replace('\n', '')
trans = trans.replace("\ufeff", "")

# %% [markdown]
# ####Text Summarizer

# %%
# !pip install transformers==4.10.0  # Replace with the version you want
# Out:
# Collecting transformers==4.10.0
#   Downloading transformers-4.10.0-py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.0.12 in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (2.31.0)
# Collecting sacremoses (from transformers==4.10.0)
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 27.3 MB/s eta 0:00:00
# Collecting tokenizers<0.11,>=0.10.1 (from transformers==4.10.0)
#   Downloading tokenizers-0.10.3.tar.gz (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.7/212.7 kB 29.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.10.0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.10.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.10.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.10.0) (2023.11.17)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.10.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.10.0) (1.3.2)
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.35.2

# %%
# from transformers import pipeline
# summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# %%
# !pip uninstall transformers
# !pip install transformers

# %%
#pipeline library in transformers, used for summaryzation
from transformers import pipeline

# %%
# pretrained model for summarization using bart using CNN daily mail dataset
bart_model ="cahya/bert-base-indonesian-522M"
summarization = pipeline('summarization', model=bart_model)
# Out:
# config.json:   0%|          | 0.00/468 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cahya/bert-base-indonesian-522M were not used when initializing BertForMaskedLM: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/230k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# The model 'BertForMaskedLM' is not supported for summarization. Supported models are ['BartForConditionalGeneration', 'BigBirdPegasusForConditionalGeneration', 'BlenderbotForConditionalGeneration', 'BlenderbotSmallForConditionalGeneration', 'EncoderDecoderModel', 'FSMTForConditionalGeneration', 'GPTSanJapaneseForConditionalGeneration', 'LEDForConditionalGeneration', 'LongT5ForConditionalGeneration', 'M2M100ForConditionalGeneration', 'MarianMTModel', 'MBartForConditionalGeneration', 'MT5ForConditionalGeneration', 'MvpForConditionalGeneration', 'NllbMoeForConditionalGeneration', 'PegasusForConditionalGeneration', 'PegasusXForConditionalGeneration', 'PLBartForConditionalGeneration', 'ProphetNetForConditionalGeneration', 'SeamlessM4TForTextToText', 'SwitchTransformersForConditionalGeneration', 'T5ForConditionalGeneration', 'UMT5ForConditionalGeneration', 'XLMProphetNetForConditionalGeneration'].

# %%
# summarized_text = summarization(full_transcript)

# %%
# summarized_text[0]['summary_text']

# %%
#summarize per 500 characters
num_iters = int(len(full_transcript)/500)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 500
  end = (i + 1) * 500
  print("INPUT TEXT")
  pprint.pprint(full_transcript[start:end])
  out = summarization(full_transcript[start:end], min_length = 5, max_length=50)
  out = out[0]
  out = out['summary_text']
  print("SUMMARY TEXT")
  pprint.pprint(out)
  summarized_text.append(out)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1281: UserWarning: Input length of input_ids is 99, but `max_length` is set to 50. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# INPUT TEXT
# ('Yang Mulia, Presiden Xi Jinping. Yang mulia para leaders hadirin sekalian '
#  'yang saya hormati. Pemimpinan terbelah kerjasama TRI tidak boleh '
#  'dipolitisasi. Ini membutuhkan upaya kita bersama dalam menjaga nilai-nilai '
#  'utama agar inisiatif ini semakin kuat dan semakin berdampak. Ada tiga hal '
#  'yang ingin saya sampaikan. untuk menjalankan proyek nasionalnya secara '
#  'mandiri, karena "sense of ownership" sangat penting untuk keberangsungan '
#  'proyek. pembangunan ibu kota baru (IKN), transisi energi, dan hiliri')
# Your max_length is set to 50, but your input_length is only 24. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# SUMMARY TEXT
# ('yang mulia, presiden xi jinping. yang mulia para leaders hadirin sekalian '
#  'yang saya hormati. pemimpinan terbelah kerjasama tri tidak boleh '
#  'dipolitisasi. ini membutuhkan upaya kita bersama dalam menjaga nilai - nilai '
#  'utama agar inisiatif ini semakin kuat dan semakin berdampak. ada tiga hal '
#  'yang ingin saya sampaikan. untuk menjalankan proyek nasionalnya secara '
#  'mandiri, karena " sense of ownership " sangat penting untuk keberangsungan '
#  'proyek. pembangunan ibu kota baru ( ikn ), transisi energi, dan hiliri.')
# INPUT TEXT
# ('sasi industri.  dan pemanfaatan produk dalam negeri. Pemimpinan Negara '
#  'Negara Berkembang melalui BRI Semoga berjaya untuk kami. ')
# SUMMARY TEXT
# ('sasi industri. dan pemanfaatan produk dalam negeri. pemimpinan negara negara '
#  'berkembang melalui bri semoga berjaya untuk kami. " " " ", ", ", ", ", ", ", '
#  '", ", ", ", "')

# %%
len(str(summarized_text))
# Out:
# 682

# %%
summary = " ".join(summarized_text)
pprint.pprint(summary)
# Out:
# ('yang mulia, presiden xi jinping. yang mulia para leaders hadirin sekalian '
#  'yang saya hormati. pemimpinan terbelah kerjasama tri tidak boleh '
#  'dipolitisasi. ini membutuhkan upaya kita bersama dalam menjaga nilai - nilai '
#  'utama agar inisiatif ini semakin kuat dan semakin berdampak. ada tiga hal '
#  'yang ingin saya sampaikan. untuk menjalankan proyek nasionalnya secara '
#  'mandiri, karena " sense of ownership " sangat penting untuk keberangsungan '
#  'proyek. pembangunan ibu kota baru ( ikn ), transisi energi, dan hiliri. sasi '
#  'industri. dan pemanfaatan produk dalam negeri. pemimpinan negara negara '
#  'berkembang melalui bri semoga berjaya untuk kami. " " " ", ", ", ", ", ", ", '
#  '", ", ", ", "')

# %%
#save summary result to txt file
result = "/content/summary_result.txt"

with open(result, "w") as file:
  file.write(summary)

print("Summary Result saved to", result)
# Out:
# Summary Result saved to /content/summary_result.txt

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
from transformers import pipeline

# Load the text from the file
file_path = '/content/transcriptgoogle.txt'  # Replace with the path to your file
with open(file_path, 'r') as file:
    transcript = file.read()

# Initialize the BART summarization model
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# Function to split the text into chunks (BART has a token limit)
def chunk_text(text, max_chunk_size=1024):
    chunks = []
    current_chunk = ""
    for sentence in text.split("."):
        if len(current_chunk) + len(sentence) < max_chunk_size:
            current_chunk += sentence + "."
        else:
            chunks.append(current_chunk)
            current_chunk = sentence + "."
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# Split the transcript into smaller chunks
transcript_chunks = chunk_text(transcript)

# Summarize each chunk and combine
summarized_text = " ".join([summarizer(chunk)[0]['summary_text'] for chunk in transcript_chunks])
print("\n\n\n")
print(summarized_text)
# Save the summarized text to a file
output_file_path = '/content/summarized_googleapi.txt'  # Replace with your desired output file path
with open(output_file_path, 'w') as output_file:
    output_file.write(summarized_text)
print("\n\n")
print(f"Summarized text saved to {output_file_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-45aa6c776968> in <cell line: 5>()
#       3 # Load the text from the file
#       4 file_path = '/content/transcriptgoogle.txt'  # Replace with the path to your file
# ----> 5 with open(file_path, 'r') as file:
#       6     transcript = file.read()
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/transcriptgoogle.txt'

# %% [markdown]
# SUMMARY INI GUE PAKE anthiago.com/transkrip BUAT TRANSKRIPNYA. TERUS SURUH CHAT GPT SUMMARY NYA

# %% [markdown]
# ##Evaluation

# %% [markdown]
# Matrix evaluation using ROUGE for BART pretrained model
#
# Doing evaluation compared summarization using BART model and human summarization

# %%
#Summary result without pretrained model -> only using pipeline from transformer
with open("transcript.txt", 'r') as file:
  data1 = file.read().replace('\n', '')
data1 = data1.replace("\ufeff","")

# %%
#Summary result using BART model
with open("summary_result.txt", 'r') as file:
  data2 = file.read().replace('\n', '')
data2 = data2.replace("\ufeff","")

# %%
# !pip install rouge

# %%
from rouge import Rouge

# %%
rouge1 = Rouge()

# %%
score = rouge1.get_scores(data1, data2, avg=True)

# %%
print(score)

# %%
import pandas as pd

# Mengubah skor ROUGE menjadi DataFrame
df_scores = pd.DataFrame(score)

# Menampilkan tabel skor
print(df_scores)

# %% [markdown]
# Matrix Evaluation using WER for wav2vec2 pretrained model
#
# Compared transcript result using API and wav2vec2

# %%
import nltk

# %%
from nltk.translate.bleu_score import corpus_bleu
import nltk
nltk.download('punkt')

# Read the text from both files
transcript_1 = '/content/transcript.txt'
transcript_google = '/content/transcriptgoogle.txt'

# %%
#Transcript result using youtube api
with open("transcriptgoogle.txt", 'r') as file:
  data3 = file.read().replace('\n', '')
data3 = data1.replace("\ufeff","")

# %%
#Transcript result using wav2vec2
with open("transcript.txt", 'r') as file:
  data4 = file.read().replace('\n', '')
data4 = data1.replace("\ufeff","")

# %%
def calculate_wer(data3, data4):
  with open("transcriptgoogle.txt", 'r') as file:
    data3 = file.read().strip().lower().split()

  with open("transcript.txt", 'r') as file:
    data4 = file.read().strip().lower().split()

  wer = nltk.edit_distance(data3, data4) / len(data3)
  return wer

# %%
ref = transcript
hyp = transcript_google

# %%
score = calculate_wer(ref, hyp)

# %%
print("WER Score :", score)

# %%
from nltk.translate.bleu_score import corpus_bleu
import nltk
nltk.download('punkt')

# Tokenizing the words in the texts
reference = [transcript_1.split()]
hypothesis = transcript_google.split()

# Calculating BLEU score for the entire texts
bleu_score = corpus_bleu([reference], hypothesis)

bleu_score
